# %%
# Initialize Azure OpenAI client
from langchain_openai import AzureChatOpenAI
from groq import Groq
import os
from doctomarkdown import DocToMarkdown
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Groq API Client

# %%
client_groq = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

app = DocToMarkdown(llm_client=client_groq, 
                    llm_model='meta-llama/llama-4-scout-17b-16e-instruct')

result = app.convert_pdf_to_markdown(
    filepath="sample_docs/sample.pdf",
    extract_images=True,
    extract_tables=True,
    output_path="markdown_output"
)

for page in result.pages:
    print(f"Page Number: {page.page_number} | Page Content: {page.page_content}")
# Out:
# Page Number: 1 | Page Content: # Reliance Retail Limited
# C/o. Reliance Corporate IT Park Limited, 17th and 18th Floor, Plot No. 5, Godrej Waterside, Sector-V, Electronics Complex, Salt Lake City, Kolkata Kolkata West Bengal 700091
#
# **(Original for Recipient)**
#
# ## Tax Invoice
#
# ### Invoice Details
# - **Invoice No**: 19R26R99999586316
# - **PAN No**: AABCR1718E
# - **Order Ref. No.**: TB0000410YD6
# - **Mode of Payment**: UPI
# - **Customer Name**: Sayantan Ghosh
# - **Jio Number**: 3454356612
#
# ### Invoice/Payment Details
# - **Invoice/Payment Date & Time**: 07 May,2025 23:06:13
# - **GST No**: 19AABCR1718E1ZM
# - **Payment Ref. No.**: 270680417732
#
# ### Customer Address
# - **Place of Supply**: 19 West Bengal
# - **Customer Address**: kalahati th, igakur para, 19, West Bengal, 713409
#
# ### Itemized List
# | Sr. No. | Item Name                                  | HSN/SAC | Qty | MRP/Unit(₹) | Discount(₹) | Taxable Amount(₹) |
# |---------|-------------------------------------------|---------|-----|--------------|--------------|-------------------|
# | 1       | JioFiber_1M_999                          | 998422  | 1   | 1038.40      | 0.00         | 880.00            |
# | 2       | Platform Services - JioFiber_1M_999      | 998439  | 1   | 140.42       | 0.00         | 119.00            |
#
# ### Tax Details
# - **Total Taxable Amount**: 999.00
#   - **CGST (9%)**: 89.91
#   - **SGST (9%)**: 89.91
# - **Total Amount(₹)**: 1178.82
#
# ### Total Amount in Words
# **One Thousand One Hundred Seventy Eight Rupees Eighty Two Paisa Only**
#
# ### Terms and Conditions
# - Telecommunication services to be provided by Reliance Jio Infocom Limited. Platform services to be provided by Jio Platforms Limited. All disputes are subjected to Mumbai Jurisdiction. Tax is not payable under Reverse Charge basis for
#
# ### Declaration
# Certified that all the particulars given above are true and correct
#
# ### Digital Signature and Details
# - Digitally signed by DS RELIANCE RETAIL LIMITED
# - Date: 2025.05.07 12:36:07IST
# - Location: 19 West Bengal
# - **Digital Signature**
#
# ### Registered Office
# Reliance Retail Limited 3rd floor, Court House, Lokmanya Tilak Marg, Dhobi Tala, Mumbai - 400002
# CIN: U01100MH1999PLC120563 [www.relianceretail.com](http://www.relianceretail.com)
# Page Number: 2 | Page Content: # Reliance Retail Limited
# C/o. Reliance Corporate IT Park Limited, 17th and 18th Floor, Plot No. 5, Godrej Waterside, Sector-V, Electronics Complex, Salt Lake City, Kolkata Kolkata West Bengal 700091
#
# **(Original for Recipient)**
#
# ## Payment Receipt
#
# ### Payment Details
# - **Payment Receipt No**: TB000041OYD6
# - **Order Ref No**: TB000041OYD6
# - **Date**: 07 May,2025 23:06:13
#
# ### Customer Information
# - **Customer Name**: Sayantan Ghosh
# - **Jio Number**: 3454356612
# - **Customer Address**: kalna m, tgakur para, 19, West Bengal, 713409
#
# ### Plan Details
# | Sr. No. | Plan Details  | Qty | MRP/Unit(₹) | Total(₹) |
# |---------|---------------|-----|--------------|-----------|
# | 1       | JioFiber_1M_999 | 1   | 1178.82     | 1178.82   |
#
# ### Total Amount
# - **Total Amount (₹)**: 1178.82
# - **Total Amount (in words)**: One Thousand One Hundred Seventy Eight Rupees Eighty Two Paise Only
#
# ### Declaration
# - **Declaration**: Certified that all the particulars given above are true and correct.
#
# ### Notes
# - This is a computer generated payment receipt, hence does not require signature.
#
# ### Registered Office
# - **Registered Office**: Reliance Retail Limited 3rd floor, Court House, Lokmanya Tilak Marg, Dhobi Taloa, Mumbai - 400002
# - **CIN**: U01100MH1999PLC120563
# - **Website**: www.relianceretail.com

# %% [markdown]
# ## Gemini API Client

# %%
from google import genai
from dotenv import load_dotenv
load_dotenv()

# Create a Gemini client
gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

app = DocToMarkdown(llm_client=gemini_client, 
                    llm_model='gemini-2.0-flash')

result = app.convert_pdf_to_markdown(
    filepath="sample_docs/sample.pdf",
    extract_images=True,
    extract_tables=True,
    output_path="markdown_output"
)

for page in result.pages:
    print(f"Page Number: {page.page_number} | Page Content: {page.page_content}")
# Out:
# LLM extraction failed for page 1: 'Client' object has no attribute 'chat'
# LLM extraction failed for page 2: 'Client' object has no attribute 'chat'
# Page Number: 1 | Page Content: Tax Invoice
# (Original for Recipient)
# Reliance Retail Limited
# C/o. Reliance Corporate IT Park Limited, 17th and 18th
# Floor, Plot No. 5, Godrej Waterside, Sector-V, Electronics
# Complex, Salt Lake City, Kolkata Kolkata West Bengal
# 700091
# Invoice No : 19R26R9999586316
# Order Ref. No. : TB000041OYD6
# PAN No : AABCR1718E
# GST No : 19AABCR1718E1ZM
# Payment Ref. No. : 270680417732
# Mode of Payment : UPI
# Invoice/Payment Date & Time : 07 May,2025 23:06:13
# Place of Supply : 19 West Bengal
# Sr.
# No.
# Item Name
# HSN/SAC
# Qty
# MRP/Unit( `)
# Discount( `)
# Taxable
# Amount( `)
# Customer Address : kalna  m, tgakur para, 19, West Bengal,
# 713409
# Jio Number : 3454356612
# Customer Name : Sayantan Ghosh
# 1
# JioFiber_1M_999
# 998422
# 1
# 1038.40
# 0.00
# 880.00
# 2
# Platform Services - JioFiber_1M_999
# 998439
# 1
# 140.42
# 0.00
# 119.00
# Total Taxable Amount
# 999.00
# 89.91
# 89.91
# CGST (9%)
# SGST (9%)
# 1178.82
# Total Amount( `)
# Total Amount (in words)
#  One Thousand One Hundred Seventy Eight Rupees Eighty Two Paisa Only
# Telecommunication services to be provided by Reliance Jio Infocomm Limited. Platform services to be provided by Jio Platforms
# Limited. All disputes are subjected to Mumbai Jurisdiction. Tax is not payable under Reverse Charge basis for
# Declaration : Certified that all the particulars given above are true and correct
# Digital Signature
# Registered Office: Reliance Retail Limited 3rd floor, Court House, Lokmanya Tilak Marg, Dhobi Talao, Mumbai - 400002
# CIN: U01100MH1999PLC120563 www.relianceretail.com
# Digitally signed by DS RELIANCE RETAIL LIMITED
# Date: 2025.05.21 12:06:07 IST
# Reason: Invoice
# Location: 19 West Bengal
# Page Number: 2 | Page Content: Reliance Retail Limited
# Payment Receipt
# C/o. Reliance Corporate IT Park Limited, 17th and 18th Floor, Plot No. 5, Godrej Waterside, Sector-V, Electronics
# Complex, Salt Lake City, Kolkata Kolkata West Bengal 700091
# (Original for Recipient)
# Payment Receipt No : TB000041OYD6
# Order Ref No : TB000041OYD6
# Date : 07 May,2025 23:06:13
# Customer Address : kalna  m, tgakur para, 19, West Bengal, 713409
# Sr. No.
# Plan Details
# Qty
# Total( `)
# MRP/Unit( `)
# Jio Number : 3454356612
# Customer Name : Sayantan Ghosh
# 1
# JioFiber_1M_999
# 1
# 1178.82
# 1178.82
# 1178.82
# Total Amount ( `)
# Total Amount (in words)
#  One Thousand One Hundred Seventy Eight Rupees Eighty Two Paisa Only
# Declaration : Certified that all the particulars given above are true and correct.
# This is a computer generated payment receipt, hence does not require signature.
# Registered Office: Reliance Retail Limited 3rd floor, Court House, Lokmanya Tilak Marg, Dhobi Talao, Mumbai - 400002
# CIN: U01100MH1999PLC120563 www.relianceretail.com
